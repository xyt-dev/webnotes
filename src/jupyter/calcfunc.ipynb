# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def xln(x):
  return x * np.log(x)
x = np.linspace(-1, 2, 1000)
y = xln(x)
plt.figure()
plt.plot(x, y)
plt.grid(True)
plt.title("$f(x)=xlnx$")
plt.show()
# Out:
# /tmp/ipykernel_117282/4126879777.py:2: RuntimeWarning: divide by zero encountered in log
#   return x * np.log(x)
# /tmp/ipykernel_117282/4126879777.py:2: RuntimeWarning: invalid value encountered in log
#   return x * np.log(x)
# /tmp/ipykernel_117282/4126879777.py:2: RuntimeWarning: invalid value encountered in multiply
#   return x * np.log(x)

# %%
print(0xfb, 0xf1, 0xc7)
# Out:
# 251 241 199
# 213 196 161
